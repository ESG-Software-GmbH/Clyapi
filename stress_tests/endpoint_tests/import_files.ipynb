# %%
import pandas as pd

df = pd.read_csv("caches/initial_import_files/cp.csv")
df = df[df.columns[:5]]
df.insert(0, "Entity_ID", "BMtwo")  # Insert new column on the left
df.to_csv("caches/parent_child_import_files/cp.csv", index=False)

df = pd.read_csv("caches/initial_import_files/ta.csv")
df = df[df.columns[:6]]
df.insert(0, "Entity_ID", "BMtwo")  # Insert new column on the left
df.to_csv("caches/parent_child_import_files/ta.csv", index=False)


df = pd.read_csv("caches/initial_import_files/it.csv")
df = df[df.columns[:7]]
df.insert(0, "Entity_ID", "BMtwo")  # Insert new column on the left
df.to_csv("caches/parent_child_import_files/it.csv", index=False)
