# %% [markdown]
# # PCR calculations
# ## Single deal

# %%
import clyapi

client = clyapi.client.Client()
pcr_result = clyapi.calculation.pcr_single_deal(client, 15, 45, "2025-01-01", "2065-01-01", "A")
print(pcr_result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import clyapi
#       3 client = clyapi.client.Client()
# ----> 4 pcr_result = clyapi.calculation.pcr_single_deal(client, 15, 45, "2025-01-01", "2065-01-01", "A")
#       5 print(pcr_result)
#
# File ~/Documents/git/Clyapi/clyapi/endpoints/calculation/pcr_single_deal.py:66, in pcr_single_deal(client, Item_Longitude, Item_Latitude, Item_Origination_Date, Item_Maturity_Date, Item_Nace_Code, Counterparty_ID, Transaction_ID, Item_ID, Score_Preset_Code, Item_Radius, Item_Center_Weight, Maximum_Assessment)
#      62     payload["Item_Center_Weight"] = Item_Center_Weight
#      63     payload["Maximum_Assessment"] = Maximum_Assessment
# ---> 66 response = requests.post(url, headers=client.get_json_header(), json=payload)
#      67 assert response.status_code == 200
#      68 return response.json()
#
# ...

# %% [markdown]
# ## Batch

# %%
# raw response
input_path = "../../data/batch_example_portfolios/pcr_input.csv"

# pcr batch with raw string result (csv pattern)
raw_result = clyapi.calculation.pcr_batch(client, input_path)

# pcr batch with
df = clyapi.calculation.pcr_batch_to_dataframe(client, input_path)
clyapi.calculation.pcr_batch_to_file(client, input_path, output_filepath="../../data/batch_output_examples/pcr_output.csv")
