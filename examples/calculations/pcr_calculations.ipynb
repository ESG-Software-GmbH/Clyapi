# %% [markdown]
# # PCR calculations
# ## Single deal

# %%
import clyapi

client = clyapi.client.Client()
pcr_result = clyapi.calculation.pcr_single_deal(client, 15, 45, "2025-01-01", "2065-01-01", "A")
print(pcr_result)

# %% [markdown]
# ## Batch

# %%
# raw response
input_path = "../../data/batch_example_portfolios/pcr_input.csv"

# pcr batch with raw string result (csv pattern)
raw_result = clyapi.calculation.pcr_batch(client, input_path)

# pcr batch with
df = clyapi.calculation.pcr_batch_to_dataframe(client, input_path)
clyapi.calculation.pcr_batch_to_file(client, input_path, output_filepath="../../data/batch_output_examples/pcr_output.csv")
# Out:
# Result files available!, polling attempt 4/30...
# successfully downloaded result file with id: f21d95c8-87a1-476c-3154-08de06832034
# Result files available!, polling attempt 3/30...
# successfully downloaded result file with id: e9b503b2-20d0-45bd-3156-08de06832034
# Result files available!, polling attempt 3/30...
# successfully downloaded result file with id: 1f685b2a-b131-4b2a-3158-08de06832034
# saved pcr portfolio as csv file to ../../data/batch_output_examples/pcr_output.csv
