# %% [markdown]
# # Example Notebook
# ## initialize client

# %%
import clyapi

client = clyapi.client.Client("Stark Bank")
print(client)
# Out:
# Active Institution:
#  Institution_Name: Stark Bank
#  Environment: Dev
#  Url_Prefix: https://api-burgundy.climcycle.com
#  Tenant_Id: 39b3a7aa-da94-46aa-99fa-f8982fef11fc
#  Resources_Id: api://a14d8f54-c6a9-49cc-92a7-b15cace0ef36/.default
#  Client_Application_Id: eb91830a-ab2f-4a7d-8ea0-290dd79415c5

# %%
institution_info = clyapi.institution.institution_info(client)
print(institution_info)
pcr_result = clyapi.calculation.physical_climate_risks_single(client, 15, 45, "2025-01-01", "2065-01-01", "A")
print(pcr_result)
# Out:
# {'institutionId': 'f2626e13-e549-425d-2fa7-08d9692cd452', 'parentInstitutionId': 'f2626e13-e549-425d-2fa7-08d9692cd452', 'applicationId': 'eb91830a-ab2f-4a7d-8ea0-290dd79415c5', 'name': 'Stark-Bank', 'code': 'GL', 'codeSeparator': '-', 'isInternal': False, 'canAccessDocumentation': True, 'canAccessEPCEvaluation': True, 'canPerformBatchCalculations': False, 'canDownloadPhysicalRisksPDF': True, 'use4EyePrinciple': False, 'useReadOnlyFields': False, 'useGeolocAppendixARecalc': False, 'canAccessTransactionItemList': True, 'forbidCreationOfNewCpAndTrx': False, 'created': '2021-08-27T07:34:50.5949015+00:00', 'usagePlanStartDate': '2021-08-27T07:34:50.5948868+00:00', 'usagePlanEndDate': '2026-08-26T22:00:00+00:00', 'isDemo': False, 'modules': None, 'isoFormat': 'ISO3', 'selectedAppTheme': 'defaultDark', 'technicalSupportEmail': 'roman.doerner@climcycle.com', 'canEnterCounterpartyKpis': True, 'canForwardQuestionnaire': True, 'canSendForwardQuestionnaireEmail': True, 'shouldForwardEmptyQuesti
# ...
