# %% [markdown]
# # Example Notebook
# ## initialize client

# %%
import clyapi

client = clyapi.client.Client()
print(client)
# Out:
# Active Institution:
#  Institution_Name: Quality Assurance Climcycle
#  Environment: Prod
#  Url_Prefix: https://api.climcycle.com
#  Tenant_Id: 1998ba70-dfcb-4c3a-bda7-a8d80d324354
#  Resources_Id: api://cb686320-988c-4884-95d0-9dc843542f1b/.default
#  Client_Application_Id: 74eb1de9-5709-4007-9bd1-615ec6e9140b

# %%
institution_info = clyapi.endpoints.institution.institution_info(client)
print(institution_info)
pcr_result = clyapi.endpoints.calculation.physical_climate_risks_single(client, 15, 45, "2025-01-01", "2065-01-01", "A")
print(pcr_result)
# Out:
# {'institutionId': 'f552331b-7e82-43dc-128f-08dbd963d926', 'parentInstitutionId': 'f552331b-7e82-43dc-128f-08dbd963d926', 'applicationId': '74eb1de9-5709-4007-9bd1-615ec6e9140b', 'name': 'Quality Assurance Climcycle', 'code': 'QACLCY', 'codeSeparator': '-', 'isInternal': False, 'canAccessDocumentation': True, 'canAccessEPCEvaluation': True, 'canPerformBatchCalculations': False, 'canDownloadPhysicalRisksPDF': True, 'use4EyePrinciple': False, 'useReadOnlyFields': False, 'useGeolocAppendixARecalc': False, 'canAccessTransactionItemList': True, 'forbidCreationOfNewCpAndTrx': False, 'created': '2023-10-30T16:21:53.9537036+00:00', 'usagePlanStartDate': '2023-10-29T23:00:00+00:00', 'usagePlanEndDate': '2029-12-31T23:00:00+00:00', 'isDemo': False, 'modules': None, 'isoFormat': 'ISO3', 'selectedAppTheme': 'default', 'technicalSupportEmail': 'roman.doerner@climcycle.com', 'canEnterCounterpartyKpis': True, 'canForwardQuestionnaire': True, 'canSendForwardQuestionnaireEmail': True, 'shouldForwardEmptyQuestionnaire': False}
# {'quota': {'remaining': 100000, 'total': 100000, 'resetTime': '2025-10-11T00:00:00+00:00'}, 'calculationStatus': 'DONE', 'data': {'River_Flood_2.6_Start': 0.0, 'River_Flood_2.6_Max': 0.0, 'River_Flood_2.6_End': 0.0, 'River_Flood_2.6_Value': 0.0, 'River_Flood_2.6_Score': 0.0, 'River_Flood_2.6_Flag': 'green', 'River_Flood_4.5_Start': 0.0, 'River_Flood_4.5_Max': 0.0, 'River_Flood_4.5_End': 0.0, 'River_Flood_4.5_Value': 0.0, 'River_Flood_4.5_Score': 0.0, 'River_Flood_4.5_Flag': 'green', 'River_Flood_8.5_Start': 0.0, 'River_Flood_8.5_Max': 0.0, 'River_Flood_8.5_End': 0.0, 'River_Flood_8.5_Value': 0.0, 'River_Flood_8.5_Score': 0.0, 'River_Flood_8.5_Flag': 'green', 'River_Flood_WAVG_Start': 0.0, 'River_Flood_WAVG_Max': 0.0, 'River_Flood_WAVG_End': 0.0, 'River_Flood_WAVG_Value': 0.0, 'River_Flood_WAVG_Score': 0.0, 'River_Flood_WAVG_Flag': 'green', 'Coastal_Flood_8.5_Start': 0.0, 'Coastal_Flood_8.5_Max': 0.0, 'Coastal_Flood_8.5_End': 0.0, 'Coastal_Flood_8.5_Value': 0.0, 'Coastal_Flood_8.5_Score': 0.0, 'Coastal_Flood_8.5_Flag': 'green', 'Coastal_Flood_WAVG_Start': 0.0, 'Coastal_Flood_WAVG_Max': 0.0, 'Coastal_Flood_WAVG_End': 0.0, 'Coastal_Flood_WAVG_Value': 0.0, 'Coastal_Flood_WAVG_Score': 0.0, 'Coastal_Flood_WAVG_Flag': 'green', 'Heavy_Precipitation_2.6_Start': 1412.8832, 'Heavy_Precipitation_2.6_Max': 1722.2664, 'Heavy_Precipitation_2.6_End': 1351.771, 'Heavy_Precipitation_2.6_Value': 1722.2664, 'Heavy_Precipitation_2.6_Score': 0.926, 'Heavy_Precipitation_2.6_Flag': 'red', 'Heavy_Precipitation_6.0_Start': 1189.5385, 'Heavy_Precipitation_6.0_Max': 1633.785, 'Heavy_Precipitation_6.0_End': 1336.2068, 'Heavy_Precipitation_6.0_Value': 1633.785, 'Heavy_Precipitation_6.0_Score': 0.8417, 'Heavy_Precipitation_6.0_Flag': 'red', 'Heavy_Precipitation_8.5_Start': 1442.3955, 'Heavy_Precipitation_8.5_Max': 1533.9772, 'Heavy_Precipitation_8.5_End': 1434.0112, 'Heavy_Precipitation_8.5_Value': 1533.9772, 'Heavy_Precipitation_8.5_Score': 0.7466, 'Heavy_Precipitation_8.5_Flag': 'red', 'Heavy_Precipitation_WAVG_Start': 1308.5889, 'Heavy_Precipitation_WAVG_Max': 1521.8314, 'Heavy_Precipitation_WAVG_End': 1364.549, 'Heavy_Precipitation_WAVG_Value': 1521.8314, 'Heavy_Precipitation_WAVG_Score': 0.7351, 'Heavy_Precipitation_WAVG_Flag': 'red', 'Snowfall_2.6_Start': 63.0433, 'Snowfall_2.6_Max': 148.4773, 'Snowfall_2.6_End': 93.1491, 'Snowfall_2.6_Value': 148.4773, 'Snowfall_2.6_Score': 0.3033, 'Snowfall_2.6_Flag': 'green', 'Snowfall_6.0_Start': 122.7386, 'Snowfall_6.0_Max': 153.9828, 'Snowfall_6.0_End': 88.7444, 'Snowfall_6.0_Value': 153.9828, 'Snowfall_6.0_Score': 0.3146, 'Snowfall_6.0_Flag': 'green', 'Snowfall_8.5_Start': 57.0334, 'Snowfall_8.5_Max': 119.5473, 'Snowfall_8.5_End': 59.9471, 'Snowfall_8.5_Value': 119.5473, 'Snowfall_8.5_Score': 0.2442, 'Snowfall_8.5_Flag': 'green', 'Snowfall_WAVG_Start': 91.3885, 'Snowfall_WAVG_Max': 121.1647, 'Snowfall_WAVG_End': 82.6462, 'Snowfall_WAVG_Value': 121.1647, 'Snowfall_WAVG_Score': 0.2475, 'Snowfall_WAVG_Flag': 'green', 'Hail_2.6_Start': 0.03, 'Hail_2.6_Max': 0.0365, 'Hail_2.6_End': 0.0288, 'Hail_2.6_Value': 0.0297, 'Hail_2.6_Score': 0.3986, 'Hail_2.6_Flag': 'yellow', 'Hail_6.0_Start': 0.0288, 'Hail_6.0_Max': 0.0394, 'Hail_6.0_End': 0.0323, 'Hail_6.0_Value': 0.0338, 'Hail_6.0_Score': 0.4217, 'Hail_6.0_Flag': 'yellow', 'Hail_8.5_Start': 0.03, 'Hail_8.5_Max': 0.0319, 'Hail_8.5_End': 0.0299, 'Hail_8.5_Value': 0.0287, 'Hail_8.5_Score': 0.3932, 'Hail_8.5_Flag': 'yellow', 'Hail_WAVG_Start': 0.0294, 'Hail_WAVG_Max': 0.0345, 'Hail_WAVG_End': 0.0308, 'Hail_WAVG_Value': 0.0315, 'Hail_WAVG_Score': 0.4088, 'Hail_WAVG_Flag': 'yellow', 'Wind_2.6_Start': 38.0025, 'Wind_2.6_Max': 38.0135, 'Wind_2.6_End': 37.8691, 'Wind_2.6_Value': 38.0135, 'Wind_2.6_Score': 0.1092, 'Wind_2.6_Flag': 'green', 'Wind_4.5_Start': 38.0025, 'Wind_4.5_Max': 38.0135, 'Wind_4.5_End': 37.308, 'Wind_4.5_Value': 38.0135, 'Wind_4.5_Score': 0.1092, 'Wind_4.5_Flag': 'green', 'Wind_6.0_Start': 38.0025, 'Wind_6.0_Max': 38.0135, 'Wind_6.0_End': 37.308, 'Wind_6.0_Value ...
